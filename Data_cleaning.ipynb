# %%
import pandas as pd

# %%
df = pd.read_csv('student3.csv')
df
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    16 non-null     int64
#  1   name    16 non-null     object
#  2   class   15 non-null     object
#  3   marks   14 non-null     float64
#  4   age     14 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 772.0+ bytes

# %%
df['name']
# Out:
# 0        anil
# 1        amit
# 2      aniket
# 3     ajinkya
# 4        asha
# 5      ayesha
# 6        amar
# 7       Amita
# 8        amol
# 9        amol
# 10      anmol
# 11     surbhi
# 12      Sujay
# 13    subhash
# 14     sachin
# 15    shalini
# Name: name, dtype: object

# %%
df['class']
# Out:
# 0      TE
# 1      TE
# 2      BE
# 3      TE
# 4      TE
# 5      BE
# 6      BE
# 7      be
# 8      TE
# 9      TE
# 10     BE
# 11     TE
# 12     TE
# 13     be
# 14    NaN
# 15     TE
# Name: class, dtype: object

# %%
df['marks']  # The error is space
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\New folder\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df['marks']
#
# ...

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks ', 'age'], dtype='object')

# %%
df['marks ']
# Out:
# 0     56.77
# 1     59.77
# 2     76.88
# 3     69.66
# 4     63.28
# 5       NaN
# 6     65.34
# 7     68.33
# 8     56.75
# 9     56.75
# 10    78.66
# 11      NaN
# 12    74.12
# 13    88.45
# 14    59.33
# 15    63.45
# Name: marks , dtype: float64

# %%
df.columns = df.columns.str.strip()

# %%
df
# Out:
#     roll     name class  marks   age
# 0      1     anil    TE  56.77  22.0
# 1      2     amit    TE  59.77  21.0
# 2      3   aniket    BE  76.88  19.0
# 3      4  ajinkya    TE  69.66  20.0
# 4      5     asha    TE  63.28   NaN
# 5      6   ayesha    BE    NaN  20.0
# 6      7     amar    BE  65.34  19.0
# 7      8    Amita    be  68.33  23.0
# 8      9     amol    TE  56.75  20.0
# 9      9     amol    TE  56.75  20.0
# 10    10    anmol    BE  78.66   NaN
# 11    11   surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  subhash    be  88.45  21.0
# 14    14   sachin   NaN  59.33  21.0
# 15    15  shalini    TE  63.45  20.0

# %%
df['marks']
# Out:
# 0     56.77
# 1     59.77
# 2     76.88
# 3     69.66
# 4     63.28
# 5       NaN
# 6     65.34
# 7     68.33
# 8     56.75
# 9     56.75
# 10    78.66
# 11      NaN
# 12    74.12
# 13    88.45
# 14    59.33
# 15    63.45
# Name: marks, dtype: float64

# %%
df['name'] = df['name'].str.title()

# %%
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    be  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    be  88.45  21.0
# 14    14   Sachin   NaN  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df['class'] = df['class'].str.title()
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    Te  56.77  22.0
# 1      2     Amit    Te  59.77  21.0
# 2      3   Aniket    Be  76.88  19.0
# 3      4  Ajinkya    Te  69.66  20.0
# 4      5     Asha    Te  63.28   NaN
# 5      6   Ayesha    Be    NaN  20.0
# 6      7     Amar    Be  65.34  19.0
# 7      8    Amita    Be  68.33  23.0
# 8      9     Amol    Te  56.75  20.0
# 9      9     Amol    Te  56.75  20.0
# 10    10    Anmol    Be  78.66   NaN
# 11    11   Surbhi    Te    NaN  23.0
# 12    12    Sujay    Te  74.12  22.0
# 13    13  Subhash    Be  88.45  21.0
# 14    14   Sachin   NaN  59.33  21.0
# 15    15  Shalini    Te  63.45  20.0

# %%
df['class'] = df['class'].str.upper()

# %%
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 9      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin   NaN  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace = True) # To drop duplicate values
df                                 # Inplace to make the changes in the original document
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin   NaN  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
## Missing values

df.dropna()  # To drop the null values
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df['marks'].fillna(df['marks'].mean())
# Out:
# 0     56.770000
# 1     59.770000
# 2     76.880000
# 3     69.660000
# 4     63.280000
# 5     67.753077
# 6     65.340000
# 7     68.330000
# 8     56.750000
# 10    78.660000
# 11    67.753077
# 12    74.120000
# 13    88.450000
# 14    59.330000
# 15    63.450000
# Name: marks, dtype: float64

# %%
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28   NaN
# 5      6   Ayesha    BE    NaN  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66   NaN
# 11    11   Surbhi    TE    NaN  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin   NaN  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df.fillna(method = 'pad') # It supstitute with the previous non null values
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14508\3734953275.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'pad') # It supstitute with the previous non null values
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28  20.0
# 5      6   Ayesha    BE  63.28  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66  20.0
# 11    11   Surbhi    TE  78.66  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin    BE  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df.isnull().sum() # give the exact null values present in the following columns
# Out:
# roll     0
# name     0
# class    1
# marks    2
# age      2
# dtype: int64

# %%
df.fillna(method = 'backfill') # It supstitute with the next non null values
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14508\1103527920.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'backfill') # It supstitute with the next non null values
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28  20.0
# 5      6   Ayesha    BE  65.34  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66  23.0
# 11    11   Surbhi    TE  74.12  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin    TE  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df.fillna(method = 'backfill',inplace = True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14508\1175304436.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'backfill',inplace = True)

# %%
df
# Out:
#     roll     name class  marks   age
# 0      1     Anil    TE  56.77  22.0
# 1      2     Amit    TE  59.77  21.0
# 2      3   Aniket    BE  76.88  19.0
# 3      4  Ajinkya    TE  69.66  20.0
# 4      5     Asha    TE  63.28  20.0
# 5      6   Ayesha    BE  65.34  20.0
# 6      7     Amar    BE  65.34  19.0
# 7      8    Amita    BE  68.33  23.0
# 8      9     Amol    TE  56.75  20.0
# 10    10    Anmol    BE  78.66  23.0
# 11    11   Surbhi    TE  74.12  23.0
# 12    12    Sujay    TE  74.12  22.0
# 13    13  Subhash    BE  88.45  21.0
# 14    14   Sachin    TE  59.33  21.0
# 15    15  Shalini    TE  63.45  20.0

# %%
df.isnull().sum()
# Out:
# roll     0
# name     0
# class    0
# marks    0
# age      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# roll     0
# name     0
# class    0
# marks    0
# age      0
# dtype: int64
